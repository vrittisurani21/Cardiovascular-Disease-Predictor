# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("Refined.csv")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df
# Out:
#        gender  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  active  \
# 0           2    62.0    110     80            1     1      0     0       1
# 1           1    85.0    140     90            3     1      0     0       1
# 2           1    64.0    130     70            3     1      0     0       0
# 3           2    82.0    150    100            1     1      0     0       1
# 4           1    56.0    100     60            1     1      0     0       0
# ...       ...     ...    ...    ...          ...   ...    ...   ...     ...
# 69971       2    76.0    120     80            1     1      1     0       1
# 69972       1   113.5    140     90            2     2      0     0       1
# 69973       2   105.0    170     90            3     1      0     1       0
# 69974       1    72.0    135     80            1     2      0     0       0
# 69975       1    72.0    120     80            1     1      0     0       1
#
#        cardio  age_years        bmi  pulse_pressure  health_index  \
# 0           0         50  21.967120              30           1.0
# 1           1         55  34.927679              50           1.0
# 2           1         51  23.507805              60           0.0
# 3           1         48  28.710479              50           1.0
# 4           0         47  23.011177              40           0.0
# ...       ...        ...        ...             ...           ...
# 69971       0         52  26.927438              40           0.5
# 69972       1         61  45.465470              50           1.0
# 69973       1         52  31.353579              80          -0.5
# 69974       1         61  27.099251              55           0.0
# 69975       0         56  24.913495              40           1.0
#
#        cholesterol_gluc_interaction
# 0                                 1
# 1                                 3
# 2                                 3
# 3                                 1
# 4                                 1
# ...                             ...
# 69971                             1
# 69972                             4
# 69973                             3
# 69974                             2
# 69975                             1
#
# [69976 rows x 15 columns]

# %%
target = 'cardio'
features = [col for col in df.columns if col != target]

# %%
X = df[features]
y = df[target]
X.shape, y.shape
# Out:
# ((69976, 14), (69976,))

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.1,
    random_state=27,
    stratify=y
)

# %%
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=27
)

# %%
rf.fit(X_train, y_train,)
# Out:
# RandomForestClassifier(random_state=27)

# %%
y_pred = rf.predict(X_test)
y_pred[:10]
# Out:
# array([1, 0, 1, 0, 0, 0, 1, 1, 0, 1], dtype=int64)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy : {accuracy:.2f}")
# Out:
# Accuracy : 0.81

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[3053,  448],
#        [ 891, 2606]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.87      0.82      3501
#            1       0.85      0.75      0.80      3497
#
#     accuracy                           0.81      6998
#    macro avg       0.81      0.81      0.81      6998
# weighted avg       0.81      0.81      0.81      6998

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
import pandas as pd

feature_importance = pd.Series(
    rf.feature_importances_,
    index=X.columns
).sort_values(ascending=False)

feature_importance
feature_importance.plot(kind='bar', figsize=(10,4))
# Out:
# <Axes: >

# %% [markdown]
# ### Save the Model

# %%
import joblib

feature_order = list(X_train.columns)

joblib.dump(
    {
        'model': rf,
        'columns': feature_order
    },
    'cardio_model.pkl',
    compress = 3
)
# Out:
# ['cardio_model.pkl']
